# %% [markdown]
# <a href="https://colab.research.google.com/github/Alkabarhatte-ind/MTechGitProject/blob/master/Baisc_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
download_url = ("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")
df = pd.read_csv(download_url)
type(df)
pd.set_option("display.max.columns", 2)
df.head()
# Out:
#     Rank  ...  Low_wage_jobs
# 0      1  ...            193
# ..   ...  ...            ...
# 4      5  ...            972
#
# [5 rows x 21 columns]

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])

# %%
import matplotlib.pyplot as plt
plt.plot(df["Rank"], df["P75th"],df["P25th"])

# %%
median_column = df["Median"]

# %%
 median_column.plot(kind="hist")

# %%
df.plot(x="Rank", y="P75th")

# %%
top_5 = df.sort_values(by="Median", ascending=False).head()
top_5.plot(x="Major", y="Median", kind="bar", rot=5, fontsize=5)

# %%
pip install pandas

# %%
df.plot(x="P25th", y="P75th", kind="scatter")
